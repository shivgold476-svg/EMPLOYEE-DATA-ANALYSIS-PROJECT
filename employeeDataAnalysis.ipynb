# %% [markdown]
# ## EMPLOYEE DATA ANALYSIS SYSTEM

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("employeedata.csv")

# %%
print(df)
# Out:
#    Employee Department  Age  Salary  Experience
# 0       Ram         IT   26   55000           3
# 1  Shivangi         IT   25  100000           1
# 2      Neha         HR   29   60000           2
# 3     Shimu    Finance   32   65000           3
# 4      Hari         HR   30   70000           4
# 5     Rosan    Finance   29   75000           5
# 6    Saniya         HR   32   69000           5
# 7     Sunny         HR   39   77000           6
# 8    Dimple    Finance   37   80000           7
# 9    Hardik    Finance   38   74000           5

# %%
df.head()
# Out:
#    Employee Department  Age  Salary  Experience
# 0       Ram         IT   26   55000           3
# 1  Shivangi         IT   25  100000           1
# 2      Neha         HR   29   60000           2
# 3     Shimu    Finance   32   65000           3
# 4      Hari         HR   30   70000           4

# %%
df.tail()
# Out:
#   Employee Department  Age  Salary  Experience
# 5    Rosan    Finance   29   75000           5
# 6   Saniya         HR   32   69000           5
# 7    Sunny         HR   39   77000           6
# 8   Dimple    Finance   37   80000           7
# 9   Hardik    Finance   38   74000           5

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Employee    10 non-null     str
#  1   Department  10 non-null     str
#  2   Age         10 non-null     int64
#  3   Salary      10 non-null     int64
#  4   Experience  10 non-null     int64
# dtypes: int64(3), str(2)
# memory usage: 532.0 bytes

# %%
df.describe()
# Out:
#              Age         Salary  Experience
# count  10.000000      10.000000   10.000000
# mean   31.700000   72500.000000    4.100000
# std     4.900113   12376.052144    1.852926
# min    25.000000   55000.000000    1.000000
# 25%    29.000000   66000.000000    3.000000
# 50%    31.000000   72000.000000    4.500000
# 75%    35.750000   76500.000000    5.000000
# max    39.000000  100000.000000    7.000000

# %%
df[["Employee","Salary"]]
# Out:
#    Employee  Salary
# 0       Ram   55000
# 1  Shivangi  100000
# 2      Neha   60000
# 3     Shimu   65000
# 4      Hari   70000
# 5     Rosan   75000
# 6    Saniya   69000
# 7     Sunny   77000
# 8    Dimple   80000
# 9    Hardik   74000

# %%
df[df["Salary"]>50000]
# Out:
#    Employee Department  Age  Salary  Experience
# 0       Ram         IT   26   55000           3
# 1  Shivangi         IT   25  100000           1
# 2      Neha         HR   29   60000           2
# 3     Shimu    Finance   32   65000           3
# 4      Hari         HR   30   70000           4
# 5     Rosan    Finance   29   75000           5
# 6    Saniya         HR   32   69000           5
# 7     Sunny         HR   39   77000           6
# 8    Dimple    Finance   37   80000           7
# 9    Hardik    Finance   38   74000           5

# %%
df[df["Department"]=="IT"]
# Out:
#    Employee Department  Age  Salary  Experience
# 0       Ram         IT   26   55000           3
# 1  Shivangi         IT   25  100000           1

# %%
df[(df["Department"]=="IT") & (df["Salary"]>50000)]
# Out:
#    Employee Department  Age  Salary  Experience
# 0       Ram         IT   26   55000           3
# 1  Shivangi         IT   25  100000           1

# %%
df.sort_values("Salary",ascending = False)
# Out:
#    Employee Department  Age  Salary  Experience
# 1  Shivangi         IT   25  100000           1
# 8    Dimple    Finance   37   80000           7
# 7     Sunny         HR   39   77000           6
# 5     Rosan    Finance   29   75000           5
# 9    Hardik    Finance   38   74000           5
# 4      Hari         HR   30   70000           4
# 6    Saniya         HR   32   69000           5
# 3     Shimu    Finance   32   65000           3
# 2      Neha         HR   29   60000           2
# 0       Ram         IT   26   55000           3

# %%
df.groupby("Department")["Salary"].max()
# Out:
# Department
# Finance     80000
# HR          77000
# IT         100000
# Name: Salary, dtype: int64

# %%
df.groupby("Department")["Salary"].min()
# Out:
# Department
# Finance    65000
# HR         60000
# IT         55000
# Name: Salary, dtype: int64

# %%
df.groupby("Department")["Salary"].mean()
# Out:
# Department
# Finance    73500.0
# HR         69000.0
# IT         77500.0
# Name: Salary, dtype: float64

# %%
df.groupby("Department")["Employee"].count()
# Out:
# Department
# Finance    4
# HR         4
# IT         2
# Name: Employee, dtype: int64

# %%
df.groupby("Department")["Salary"].sum()
# Out:
# Department
# Finance    294000
# HR         276000
# IT         155000
# Name: Salary, dtype: int64

# %%
df.groupby("Department")["Salary"].agg(["mean","max","min","sum","count"])
# Out:
#                mean     max    min     sum  count
# Department
# Finance     73500.0   80000  65000  294000      4
# HR          69000.0   77000  60000  276000      4
# IT          77500.0  100000  55000  155000      2

# %%
df["Department"].value_counts()
# Out:
# Department
# HR         4
# Finance    4
# IT         2
# Name: count, dtype: int64

# %%
df["Department"].unique()
# Out:
# <StringArray>
# ['IT', 'HR', 'Finance']
# Length: 3, dtype: str

# %%
df["Department"].nunique()
# Out:
# 3

# %%
df.isnull()
# Out:
#    Employee  Department    Age  Salary  Experience
# 0     False       False  False   False       False
# 1     False       False  False   False       False
# 2     False       False  False   False       False
# 3     False       False  False   False       False
# 4     False       False  False   False       False
# 5     False       False  False   False       False
# 6     False       False  False   False       False
# 7     False       False  False   False       False
# 8     False       False  False   False       False
# 9     False       False  False   False       False

# %%
df.isnull().sum()
# Out:
# Employee      0
# Department    0
# Age           0
# Salary        0
# Experience    0
# dtype: int64

# %%
df["Age"].fillna(29)
df.dropna()
# Out:
#    Employee Department  Age  Salary  Experience
# 0       Ram         IT   26   55000           3
# 1  Shivangi         IT   25  100000           1
# 2      Neha         HR   29   60000           2
# 3     Shimu    Finance   32   65000           3
# 4      Hari         HR   30   70000           4
# 5     Rosan    Finance   29   75000           5
# 6    Saniya         HR   32   69000           5
# 7     Sunny         HR   39   77000           6
# 8    Dimple    Finance   37   80000           7
# 9    Hardik    Finance   38   74000           5

# %%
dept_salary = df.groupby("Department")["Salary"].mean()
plt.figure(figsize =(6,4))
dept_salary.plot(kind = "bar")
plt.title("Average Salary Department")
plt.xlabel("Department")
plt.ylabel("Average Salary")
plt.show()

# %%
dept_count = df["Department"].value_counts()
plt.figure(figsize = (6,6))
dept_count.plot(kind= "pie",autopct ="%1.1f%%")
plt.title("Employees by Department")
plt.ylabel("")
plt.show()

# %%
plt.figure(figsize=(6,4))
df["Salary"].plot(kind="hist",bins=5)
plt.title("Salary Distribution")
plt.xlabel("Salary Range")
plt.ylabel("Frequency")
plt.show()
